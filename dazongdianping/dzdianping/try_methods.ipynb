# %%
# -*- coding: UTF-8 -*-
import urllib
import random
from urllib import request
from bs4 import BeautifulSoup
import random
import json
from requests import Session
import time

# %%
# 获取IP列表
# res = request.urlopen(apiUrl).read().decode('utf-8').strip('\n')
    
# 按照\n分割获取到的IP
# ips = res.split("\n")
# 随机选择一个IP
# proxyip = random.choice(ips)
    
# proxy = {}
# proxy['http'] = proxyip

    
# 使用代理IP请求目标网址
# proxy_support = request.ProxyHandler(proxy)
# opener = request.build_opener(proxy_support)
# request.install_opener(opener)
    
    
my_headers=[
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.48"
        ]
    
random_header=random.choice(my_headers)
my_header = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'
    
i_headers = {'User-Agent':my_header,
             'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
             'Connection':'keep-alive',
             'Cookie':'_hc.v=c019a1eb-4454-098b-587e-5628e182c145.1500469542; __utma=1.700918548.1500792539.1500792539.1500946306.2; __utmz=1.1500792539.1.1.utmcsr=dianping.com|utmccn=(referral)|utmcmd=referral|utmcct=/beijing/beauty; s_ViewType=10; _lxsdk_cuid=15dc5d06819c8-0efdaeafcc9ebe-1c2f170b-100200-15dc5d06819c8; _lxsdk=15dc5d06819c8-0efdaeafcc9ebe-1c2f170b-100200-15dc5d06819c8; PHOENIX_ID=0a010725-15dc5fb41e7-3f291d9; __mta=252547766.1502262372220.1502262372220.1502265164916.2; JSESSIONID=A0AEB34CA305168496A5A64EB8FACC5B; aburl=1; cy=1; cye=shanghai; _lx_utm=utm_source%3Ddianping.com%26utm_medium%3Dreferral%26utm_content%3D%252Fbeijing%252Fbeauty; _lxsdk_s=15dcb7aee21-0f9-425-cd4%7C%7C14',
             'Host':'www.dianping.com'}

req = request.Request(url,headers=i_headers)
html = request.urlopen(req).read().decode('utf-8')

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script>(function(n){var e;e="//catdot.dianping.com/broker-service/api/js",n.onerror=function(n,o,r){var i=encodeURIComponent,t=+new Date();(new Image).src=e+"?error="+i(n)+"&file="+i(o)+"&line="+i(r)+"&timestamp="+t}})(window);</script>
# <title>宋记香辣蟹(日月光中心广场店)电话,地址,营业时间(图)-上海美食-大众点评网</title>
# <script>
#     document.documentElement.className = location.hash ? 'J_H' : '';
#
#     !(function (win, doc, ns) {
#         var cacheFunName = '_MeiTuanALogObject';
#         win[cacheFunName] = ns;
#         if (!win[ns]) {
#             var _LX = function () {
#                 _LX.q.push(arguments);
#                 return _LX;
#             };
#             _LX.q = _LX.q || [];
#             _LX.l = +new Date();
#             win[ns] = _LX;
#         }
#     })(window, document, 'LXAnalytics');
#
#     var G_rtop = +new Date,
#             _gaq = [
# ...

# %%
comments = soup.find('div', {'id':'comment', 'class':'mod comment'}).findAll('p', {'class':'desc J-desc'})
for comment in comments:
    print(comment.get_text())
# Out:
# 在打浦桥地铁站下，先在田子坊下午逛了一下，晚上想着吃饭无意中找到了这个日月光中心广场。这家店就在四楼，四楼每家店都排好多人，这家来的时候还不是很多人。主要吃香辣蟹的。有香辣蟹，虾，牛蛙等各种锅。然后可以加些配菜放在里面一起炒，有点像麻辣香锅。价格不贵，中辣感觉像微辣，味道不是很重。虾还比较大，食材比较新鲜。最近还在做花甲半价和送杨枝甘露，领券登活动。整体还不错吧！
# 在日月光四楼兜啦一圈 和朋友很默契地都想吃这家蟹 口味：我们都很爱吃蟹 就选了小份的蟹 加了四个配菜 朋友不太吃辣 就选的中辣 于我而言根本没味道好吧🙃 万万没想到端上来一大锅 哈哈 分量还不错 啃啊啃 聊啊聊 从中餐吃成晚饭😳我吃过太多干锅 这家味道并没有惊艳我 不过无过 吃到最后非常咸...狂喝水...要为这家的【满杯西柚】点个赞 不输什么喜茶嘛 很好喝呢 清爽！满杯西柚香 是我喜欢的味道！环境：很明亮... 怎么说呢 像90年代很富贵的酒店🌚 不是我喜欢的风格价格：人均110吧～ 分量还不错 吃了三个小时...
# 家里人中到的霸王餐，提早一天电话订位了，隔天早早来到了店里，店里已经预留了VIP的位子，现在有活动扫二维码就可以送杨枝甘露和半价的花甲。 点了牛蛙和基围虾，两样都要了香辣微辣的，点菜时店长说明了两份都会加的配菜提醒我不要重复点了这点不错，等菜期间店家上了小碟的开胃菜还被告知可以送绵绵冰，过了一会儿菜陆续上桌了，因为天热胃口不大好就都点了小份的但是实际上小份份量也蛮多的，菜品比较新鲜口味不错，期间服务员还会询问对菜品的咸淡口味是否满意，还会不停的换骨盆，态度真心好，是一次愉快的体验
# 好嗨森啊，又抽到了大众的霸王餐，宋记香辣蟹，走起~开在日月光的这家，生意蛮好的，由服务员领导就座到告知霸王餐，然后验券一气呵成，毫无拖沓，服务态度也是杠杠的~下完单后服务员会主动询问需不需要湿巾，不需要的会自动帮你拿掉，这点我觉得很好，初次之外还送了绵绵冰，有花生和芒果味可供选择，我们点的芒果味的，不同于甜品店的绵绵冰，他们家是没有芒果果肉的，味道还可以吧。他们家的蟹煲比较精，点的香辣蟹的锅，和别家的区别是里面没有凤爪和土豆等料，但很入味，里面的笋块也很嫩。
# ...

# %%
comment_all_url = soup.find('p', {'class':'comment-all'}).find('a')

comment_all_url
# Out:
# <a href="/shop/16789967/review_more#start=10" rel="nofollow" target="_blank" title="">更多点评(21900)</a>

# %%
comment_all_url = comment_all_url.attrs['href']

# %%
targeturl = 'https://www.dianping.com/shop/16789967/review_more'+str(comment_all_url)

# %%
req = request.Request(url,headers=i_headers)
html = request.urlopen(req).read().decode('utf-8')

# %%
soup_comment = BeautifulSoup(html, 'lxml')

# %%
soup_comment
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script>(function(n){var e;e="//catdot.dianping.com/broker-service/api/js",n.onerror=function(n,o,r){var i=encodeURIComponent,t=+new Date();(new Image).src=e+"?error="+i(n)+"&file="+i(o)+"&line="+i(r)+"&timestamp="+t}})(window);</script>
# <title>宋记香辣蟹(日月光中心广场店)电话,地址,营业时间(图)-上海美食-大众点评网</title>
# <script>
#     document.documentElement.className = location.hash ? 'J_H' : '';
#
#     !(function (win, doc, ns) {
#         var cacheFunName = '_MeiTuanALogObject';
#         win[cacheFunName] = ns;
#         if (!win[ns]) {
#             var _LX = function () {
#                 _LX.q.push(arguments);
#                 return _LX;
#             };
#             _LX.q = _LX.q || [];
#             _LX.l = +new Date();
#             win[ns] = _LX;
#         }
#     })(window, document, 'LXAnalytics');
#
#     var G_rtop = +new Date,
#             _gaq = [
# ...

# %%
comment_all = []
comments = soup_comment.findAll('p', {'class':'desc J-desc'})
for comment in comments:
    comment_all.append(comment.get_text())
    print(comment.get_text())
# Out:
# 在打浦桥地铁站下，先在田子坊下午逛了一下，晚上想着吃饭无意中找到了这个日月光中心广场。这家店就在四楼，四楼每家店都排好多人，这家来的时候还不是很多人。主要吃香辣蟹的。有香辣蟹，虾，牛蛙等各种锅。然后可以加些配菜放在里面一起炒，有点像麻辣香锅。价格不贵，中辣感觉像微辣，味道不是很重。虾还比较大，食材比较新鲜。最近还在做花甲半价和送杨枝甘露，领券登活动。整体还不错吧！
# 在日月光四楼兜啦一圈 和朋友很默契地都想吃这家蟹 口味：我们都很爱吃蟹 就选了小份的蟹 加了四个配菜 朋友不太吃辣 就选的中辣 于我而言根本没味道好吧🙃 万万没想到端上来一大锅 哈哈 分量还不错 啃啊啃 聊啊聊 从中餐吃成晚饭😳我吃过太多干锅 这家味道并没有惊艳我 不过无过 吃到最后非常咸...狂喝水...要为这家的【满杯西柚】点个赞 不输什么喜茶嘛 很好喝呢 清爽！满杯西柚香 是我喜欢的味道！环境：很明亮... 怎么说呢 像90年代很富贵的酒店🌚 不是我喜欢的风格价格：人均110吧～ 分量还不错 吃了三个小时...
# 家里人中到的霸王餐，提早一天电话订位了，隔天早早来到了店里，店里已经预留了VIP的位子，现在有活动扫二维码就可以送杨枝甘露和半价的花甲。 点了牛蛙和基围虾，两样都要了香辣微辣的，点菜时店长说明了两份都会加的配菜提醒我不要重复点了这点不错，等菜期间店家上了小碟的开胃菜还被告知可以送绵绵冰，过了一会儿菜陆续上桌了，因为天热胃口不大好就都点了小份的但是实际上小份份量也蛮多的，菜品比较新鲜口味不错，期间服务员还会询问对菜品的咸淡口味是否满意，还会不停的换骨盆，态度真心好，是一次愉快的体验
# 好嗨森啊，又抽到了大众的霸王餐，宋记香辣蟹，走起~开在日月光的这家，生意蛮好的，由服务员领导就座到告知霸王餐，然后验券一气呵成，毫无拖沓，服务态度也是杠杠的~下完单后服务员会主动询问需不需要湿巾，不需要的会自动帮你拿掉，这点我觉得很好，初次之外还送了绵绵冰，有花生和芒果味可供选择，我们点的芒果味的，不同于甜品店的绵绵冰，他们家是没有芒果果肉的，味道还可以吧。他们家的蟹煲比较精，点的香辣蟹的锅，和别家的区别是里面没有凤爪和土豆等料，但很入味，里面的笋块也很嫩。
# ...

# %%
basic_url = 'https://www.dianping.com/shop/16789967/review_more'
next_url = '?pageno=1'
target_url = basic_url + next_url

# %%
my_header = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'
    
i_headers = {'User-Agent':my_header,
             'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
             'Connection':'keep-alive',
             'Host':'www.dianping.com'}

# req = request.Request(url,headers=i_headers)
# html = request.urlopen(req).read().decode('utf-8')
url = "https://www.dianping.com/shop/16789967/review_more?pageno=1"
s = Session()
html = s.post(url, headers=i_headers).text

# %%
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="G_N">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>宋记香辣蟹(日月光中心广场店)的全部评价-上海-大众点评网</title>
# <script>
#     document.documentElement.className=location.hash?'J_H':'';
#     var G_rtop=+new Date,
#         _gaq=[
#         ['_setAccount','UA-464026-1'],
#         ['_addOrganic','soso','w'],
#         ['_addOrganic','sogou','query'],
#         ['_addOrganic','yodao','q'],
#         ['_addOrganic','bing','q'],
#         ['_addOrganic','360','q'],
#         ['_addOrganic','gougou','search'],
#         ['_setDomainName', '.dianping.com']
#         ,['_setAllowHash', false]
#
#         ],
#         dpga=function(key){_gaq.push(['_trackPageview', key||''])},
#         pageTracker={_trackPageview:dpga},
#         _hip=[
#             ['_setPageId', 13],
#             ['_setCityId', 1],
#             ['_setShopType', 0],
#             ['_setPVInitData', {p_render:+(new Date)-G_rtop}]
#         ];
# </script>
# ...

# %%
soup.findAll('div', {"class":"J_brief-cont"})
# Out:
# [<div class="J_brief-cont">
#                          姐妹小聚第一次吃香辣蟹，没有想象中那么辣，倒是真的咸，喝了好多水。<br/>分享朋友圈送了杨枝甘露，又恰好遇到花蛤半价，花蛤没有沙，有淡淡奶香，口味相对不那么咸好评。<br/>服务员换盘非常勤快，也会上前询问口味，建议我们下次备注好不要太咸…
#                  </div>, <div class="J_brief-cont">
#                          偶尔去吃味道还可以吧，量可以，价格也还行
#                  </div>, <div class="J_brief-cont">
#                          点一份大份的香辣蟹，好久没有吃了。<br/>味道，有点咸，希望商家看了能够改良。<br/>因为有活动点了一份半价的花蛤，可能吃泻吃的麻木了，感觉花蛤淡而无味，但是重点是花蛤没有沙，还是不错的，价格如果不是半价，觉得性价比就不高了。<br/>香辣蟹，量肯定不多，大份也是如此，别指望吃饱，点了一些配菜，魔芋丝笋尖午餐肉蟹肉棒，有点像吃干锅了。<br/>分享朋友圈送杨枝甘露，蛮好喝的。
#                  </div>, <div class="J_brief-cont">
#                          又是长长的等号排队，不过好东西等等也值得，两个人点的中等锅，加了年糕和大肠，其他的朋友点，做蟹时间有点长，等的有些无聊了，味道很棒，香辣可口，蟹肉也很鲜美，蟹敲的也很碎，吃起来很方便，其他的添加菜也很入味，会再来
#                  </div>, <div class="J_brief-cont">
#                          每次稍微去晚点就得排队，味道比较重口，说是香辣蟹，其实就是升级版的麻辣香锅
#                  </div>, <div class="J_brief-cont">
#                          味道还可以 就是老板空调不开大 省钱 室内30℃
# ...

# %%
test = []
comments = soup.findAll('div', {"class":"J_brief-cont"})
for comment in comments:
    test.append(comment.get_text().split())

# %%
test
# Out:
# [['姐妹小聚第一次吃香辣蟹，没有想象中那么辣，倒是真的咸，喝了好多水。分享朋友圈送了杨枝甘露，又恰好遇到花蛤半价，花蛤没有沙，有淡淡奶香，口味相对不那么咸好评。服务员换盘非常勤快，也会上前询问口味，建议我们下次备注好不要太咸…'],
#  ['偶尔去吃味道还可以吧，量可以，价格也还行'],
#  ['点一份大份的香辣蟹，好久没有吃了。味道，有点咸，希望商家看了能够改良。因为有活动点了一份半价的花蛤，可能吃泻吃的麻木了，感觉花蛤淡而无味，但是重点是花蛤没有沙，还是不错的，价格如果不是半价，觉得性价比就不高了。香辣蟹，量肯定不多，大份也是如此，别指望吃饱，点了一些配菜，魔芋丝笋尖午餐肉蟹肉棒，有点像吃干锅了。分享朋友圈送杨枝甘露，蛮好喝的。'],
#  ['又是长长的等号排队，不过好东西等等也值得，两个人点的中等锅，加了年糕和大肠，其他的朋友点，做蟹时间有点长，等的有些无聊了，味道很棒，香辣可口，蟹肉也很鲜美，蟹敲的也很碎，吃起来很方便，其他的添加菜也很入味，会再来'],
#  ['每次稍微去晚点就得排队，味道比较重口，说是香辣蟹，其实就是升级版的麻辣香锅'],
#  ['味道还可以', '就是老板空调不开大', '省钱', '室内30℃'],
#  ['今天一天在外面培训～离日月光很近～mobike过来只要几分钟～因为是工作日的中午所以人不多～也不用等位～三个人点了大份的香辣蟹再加了金针菇和鸭掌～这里环境好～服务更好～味道一如既往～大众点评团购也还算划算～'],
#  ['朋友们聚会的地方，已经第二次来了，还是感觉挺好的。干锅，不吃蟹就吃牛蛙还有肥肠吧，都很不错。然后加的配料也可以选择不少，一个人来有些费劲，还是多些人来比较过瘾。上次在这边貌似点多了，这次吸取了教训，都挺好了。估计下次要是约在这边唱歌的话，这家还会是首选'],
#  ['和闺蜜约会的店，菜量大，吃了好撑'],
#  ['点的香辣的微辣', '金牌香辣蟹和牛蛙', '原来牛蛙是馋嘴牛蛙不是干锅牛蛙', '香辣蟹不是太入味'],
#  ['朋友积极安利的店，感觉就是干锅似的，和肉蟹煲差不多，就是肉蟹煲汤汁浓厚多一些。说实话，螃蟹不是太新鲜，口味也就是这样了，服务挺好，骨碟换的很勤，有个点菜的小姐姐估计是领班吧，对其他员工的语气不要太厉害哟。糍粑很好吃。'],
# ...

# %%
comment_all = []
basic_url = 'https://www.dianping.com/shop/16789967/review_more'
next_url = '?pageno=1'
target_url = basic_url + next_url
count = 1
html = s.post(target_url, headers=i_headers).text
soup = BeautifulSoup(html, 'lxml')

while soup.find('a', {"class":"NextPage"}):
    print(u"抓取第"+str(count)+"页评论......")
#     print(target_url+".....")
    next_url = soup.find('a', {"class":"NextPage"}).attrs['href']
    comments = soup.findAll('div', {"class":"J_brief-cont"})
    for comment in comments:
        comment_all.append(comment.get_text().split())
#     print(comment_all)
    if count % 5 == 0:
        f = open("a.txt", "w")
        f.write(str(comment_all))
        f.close()
    target_url = basic_url + next_url
    sleep_time = random.randint(15, 60)
    time.sleep(sleep_time)
    html = s.post(target_url, headers=i_headers).text
    soup = BeautifulSoup(html, 'lxml')
    count += 1

comments = soup.findAll('div', {"class":"J_brief-cont"})
for comment in comments:
    comment_all.append(comment.get_text().split())
f = open("a.txt", "w")
f.write(str(comment_all))
f.close()
print("Done!")
# Out:
# 抓取第1页评论......
# 抓取第2页评论......
# 抓取第3页评论......
# 抓取第4页评论......
# 抓取第5页评论......
# 抓取第6页评论......
# 抓取第7页评论......
# 抓取第8页评论......
# 抓取第9页评论......
# 抓取第10页评论......
# 抓取第11页评论......
# 抓取第12页评论......
# 抓取第13页评论......
# 抓取第14页评论......
# 抓取第15页评论......
# 抓取第16页评论......
# 抓取第17页评论......
# 抓取第18页评论......
# 抓取第19页评论......
# 抓取第20页评论......
# 抓取第21页评论......
# 抓取第22页评论......
# 抓取第23页评论......
# 抓取第24页评论......
# 抓取第25页评论......
# 抓取第26页评论......
# 抓取第27页评论......
# 抓取第28页评论......
# 抓取第29页评论......
# 抓取第30页评论......
# 抓取第31页评论......
# 抓取第32页评论......
# 抓取第33页评论......
# 抓取第34页评论......
# 抓取第35页评论......
# 抓取第36页评论......
# 抓取第37页评论......
# 抓取第38页评论......
# 抓取第39页评论......
# 抓取第40页评论......
# 抓取第41页评论......
# 抓取第42页评论......
# 抓取第43页评论......
# 抓取第44页评论......
# 抓取第45页评论......
# 抓取第46页评论......
# 抓取第47页评论......
# 抓取第48页评论......
# 抓取第49页评论......
# 抓取第50页评论......
# 抓取第51页评论......
# 抓取第52页评论......
# 抓取第53页评论......
# 抓取第54页评论......
# 抓取第55页评论......
# 抓取第56页评论......
# 抓取第57页评论......
# 抓取第58页评论......
# 抓取第59页评论......
# ...
